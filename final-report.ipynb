# %% [markdown]
# # The battle of the neighborhoods
#
# # Week
#
# ## Title- Business recommender system

# %% [markdown]
# ## Business Problem:

# %% [markdown]
# Toronto is one of the largest cities of Canada and the provincial capital of Ontario. It is the financial capital of Canada. So a person would often llike to start a new business here. So the question arises, what kind of business should he start? Where should he start it? And what are his chances for success? These are the questions which are of utmost importance to a aspiring bussinessman/woman.

# %% [markdown]
# So it is very tough for the aspiring businessman/businesswoman to get the answers to the above questions on his own and they cannot be left on luck as these factors directly influence the success of his/her business. So my analysis aims at using the Foursquare api to provide the concerned person with the list of most common to the least common businesses present in the area so that he/she could choose to set up the business which is not common in a particular neighbourhood and that could lead to the success of his/her business.

# %% [markdown]
# # Data sources(week4-part B)

# %% [markdown]
# For this study the data was extracted from a wikipedia page that had all the information needed to explore and cluster the neighbourhoods of Toronto. Foursquare's location data was also used to extract the information about the venues present in or around the neighbourhood. The link to the wikipedia page is provided here-https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M

# %% [markdown]
# The list of venues present in the various neighbourhoods was extracted and the list was grouped by neighbourhoods. Eventually a list of venues ranging from most common to least common in a neighbourhood was presented.

# %% [markdown]
# ## Data collection and methodology

# %% [markdown]
# 1. The list of various neighbourhoods along with their postal codes was picked from a wikipedia page(https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M).

# %% [markdown]
# 2. The beautiful soup library was used to parse the table available on the wikipedia page and converted into a list. The list in turn was used to create a pandas dataframe.
# ![image.png](attachment:image.png)

# %% [markdown]
# 3.Then a csv file containing the geospatial data of the neighbourhoods was read and the latitude and longitude data of the neighbourhoods was merged into the table.
# ![image.png](attachment:image.png)

# %% [markdown]
# 4.Then a map was created using the folium library showing the location of various neighbourhoods in the library.
# 5.Foursquare's api was used to extract the information about the venues and businesses present in all the neighbourhoods and another dataframe was created.![image.png](attachment:image.png)

# %% [markdown]
# 6.Then the venues/businesses ranging from most common to least common for each neighbourhood was listed.![image.png](attachment:image.png)

# %% [markdown]
# ### Results:

# %% [markdown]
# As a result we were abe to list down all the neighbourhoods and the most common and the least common businesses present in them which in turn would directly help a person in deciding what kind of business he/she should start in what part of the city.

# %% [markdown]
# ### Conclusion

# %% [markdown]
# Using this report we were able to conclude that casual eating joints are the most common businesses present in each neighbourhood.
